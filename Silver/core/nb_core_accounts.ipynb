# %% [markdown]
# #Core Buisness Logic for Accounts

# %% [markdown]
# ## Importing data

# %%
import pyspark.sql.functions as F

# %%
df_silver_account=spark.table("silver.transformation.accounts")

# %%
df_silver_account.display()

# %% [markdown]
# ## Writing to core

# %%
df_silver_account.write.mode("overwrite").saveAsTable("silver.core.accounts")
